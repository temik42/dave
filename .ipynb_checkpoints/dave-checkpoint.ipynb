# %%
# %matplotlib inline
from scipy.io import *
import numpy as np
import matplotlib.pyplot as plt
import sys
from dave import DAVE
from scipy.ndimage.filters import gaussian_filter

# %%
idx = np.mgrid[0:64,0:64,0:64]

temp = 10*np.exp(-(idx[0]-idx[2])**2./2/9-(idx[1]-32)**2./2/9) + np.random.random((64,64,64))
g = np.gradient(temp)

# %%
q = DAVE(temp,(5.,5.,5.)).run()
x = q.get()

# %%
plt.figure(figsize=(8,8))
plt.imshow(g[2][:,:,32])
plt.quiver(x[1,:,:,32],x[0,:,:,32])

# %%
np.max(np.abs(x[0,:,:,:]))
# Out:
# nan

# %%
s = np.load('Q:\\data\\20110225\\sdo.x766y1118.20110225.npz')
data = np.transpose(np.float32(s['hmi']),(1,2,0))
k = 127

# %%
q = DAVE(data,(5.,5.,5.)).run()

# %%
x = q.get()

# %% [markdown]
# <h2>Differential Affine Velocity Estimator (DAVE) ($Schuck, ApJ 2006$):
#
# <p>$C(\xi,\tau,\Delta t,P) = \Delta t^2 \displaystyle\int d t d^2x w(x-\xi,t-\tau)\{\frac{\partial B_n(x,t)}{\partial t} +
# \nabla_t \cdot [B_n(x,t)v_t(P,x)]\}^2$

# %%
k = 80
plt.figure(figsize = (10,10))
plt.title('Local velocity field (DAVE)', size = 20)
plt.imshow(data[:,:,k])
plt.quiver(x[0,:,:,k], x[1,:,:,k])

# %%
sys.path.append('Q:\\python\\lib')
from pyfield import *

dim = data.shape[1:3]+(64,)

B1 = np.gradient(-PField(data[k,:,:], 64))

idx = np.indices(dim).astype(np.float32)  
X = np.zeros(dim+(4,), dtype = np.float32)
B = np.zeros(dim+(4,), dtype = np.float32)
V = np.zeros(data.shape+(8,), dtype = np.float32)

X[:,:,:,0] = idx[0,:,:,:] - dim[0]/2
X[:,:,:,1] = idx[1,:,:,:] - dim[1]/2
X[:,:,:,2] = idx[2,:,:,:] - dim[2]/2
X[:,:,:,3] = 1.



for i in range(0,64):
    X[:,:,i,0] += x[0,k,:,:]*np.exp(-i/32.)
    X[:,:,i,1] += x[1,k,:,:]*np.exp(-i/32.)

B[:,:,:,0] = B1[0]
B[:,:,:,1] = B1[1]
B[:,:,:,2] = B1[2]

V[:,:,:,0] = np.transpose(x[0,:,:,:], (1,2,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-31299815f8a3> in <module>()
#      26 B[:,:,:,2] = B1[2]
#      27
# ---> 28 V[:,:,:,0] = np.transpose(x[0,:,:,:], (1,2,0))
#
# ValueError: could not broadcast input array from shape (64,64,481) into shape (481,64,64)

# %%
sys.path.append('Q:\\python\\opencl-rotB')
from window import *
import rotB

cle = rotB.Integrator(X, B, 1e4)
cle.start()
    
#window(cle, video_dir = '/video')

# %%
cle.stop()

# %%
plt.figure(figsize = (16,8))
#plt.imshow(cle._Current[:,:,4,1])
plt.subplot(121)
plt.title('HMI magnetogram', size = 18)
plt.imshow(B[:,:,0,2])
plt.subplot(122)
plt.title('Absolute value of current on height h=3', size = 18)
plt.imshow(np.sqrt(np.sum(cle._Current[:,:,3,:]**2,axis=2)))

# %%
temp = s['aia_171'][500,:,:]
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.title('AIA 171 image', size = 18)
plt.imshow(temp)
plt.subplot(122)
plt.title('Absolute value of current on height h=3', size = 18)
plt.imshow(np.sqrt(np.sum(cle._Current[:,:,3,:]**2,axis=2)))
